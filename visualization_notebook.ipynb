# %% [markdown]
# # Import visualization methods

# %%
import visualization as vis

# %% [markdown]
# # Visualization

# %% [markdown]
# ## 1.   Show the data of a Selected Country/Region

# %% [markdown]
# ### 1.1 Show all data for Canada

# %%
vis.show_cnty_for_days(cnty='CAN', history=-1)

# %% [markdown]
# ### 1.2 Show the data of Hong Kong for the past 90 days

# %%
vis.show_cnty_for_days(cnty='HKG', history=90)

# %% [markdown]
# ## 2. Show the data of a list of Selected Countries/Regions.

# %% [markdown]
# ### 2.1 Show the data of Canada, the United States, the United Kingdom, Japan, Hong Kong, Italy and South Korea for the past 60 days

# %%
vis.show_selected_cnty_with_per_million_for_days(cnty=['CAN', 'USA', 'GBR', 'JPN', 'HKG', 'ITA', 'KOR'], history=60)

# %% [markdown]
# ### 2.2 Show the data of France for the past 90 days

# %%
vis.show_selected_cnty_with_per_million_for_days(cnty='FRA', history=90)

# %% [markdown]
# ### 2.3 Show the data of a country with invalid ```iso3``` (Canada will be shown instead) for the past 60 days

# %%
vis.show_selected_cnty_with_per_million_for_days(cnty='AAA', history=60)

# %% [markdown]
# ## 3. Show the Top n Countries/Regions with the Highest Average Number of New Cases

# %% [markdown]
# ### 3.1 Show the top 5 countries/regions with the highest average number of new daily cases in the past 14 days, in 60-day history charts

# %%
vis.show_avg_highest_cases_for_days(per_1m=False, no_of_cnty=5, avg_cases=14, history=60)

# %% [markdown]
# ### 3.2 Show the top 5 countries/regions with the highest average number of new daily cases per 1 million people in the past 14 days, in 60-day history charts

# %%
vis.show_avg_highest_cases_for_days(per_1m=True, no_of_cnty=5, avg_cases=14, history=60)

# %% [markdown]
# ## 4. Show the Top n Countries/Regions with the Highest Total Number of Cases

# %% [markdown]
# ### 4.1 Show the top 5 countries/regions for 90-day charts

# %%
vis.show_highest_cases_in_all_time(5, history=90)
